# %%
import numpy as np
import pandas as pd
import regex as re
import requests
import time

# %%
apikey = ''

# %%
del apikey

# %% [markdown]
# Article Search documentation
#
# https://developer.nytimes.com/docs/articlesearch-product/1/overview
#
# Article Search example, parameters, and testing
#
# https://developer.nytimes.com/docs/articlesearch-product/1/routes/articlesearch.json/get

# %% [markdown]
# ### Testing API

# %%
url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'

res = requests.get(
    url,
    params = {
        'begin_date': '20120101',
        'end_date': '20200101',
        'sort': 'newest',
        'page': '0',
        
        'type': 'article',
        'q': 'flood',
        'fq': 'subject:("Floods")',
        'api-key': apikey
    }
)
assert res.status_code == 200

# %%
res.json()['response']['meta']
# Out:
# {'hits': 1244, 'offset': 0, 'time': 298}

# %%
res.json()['response']['docs'][0].keys()
# Out:
# dict_keys(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section', 'print_page', 'source', 'multimedia', 'headline', 'keywords', 'pub_date', 'document_type', 'news_desk', 'section_name', 'subsection_name', 'byline', 'type_of_material', '_id', 'word_count', 'uri'])

# %%
res.json()['response']['docs'][0]
# Out:
# {'abstract': 'A series of winter storms unleashed heavy rain and strong winds across Portugal, Spain, France and Britain.',
#  'web_url': 'https://www.nytimes.com/2019/12/22/world/europe/storm-elsa-fabien-floods.html',
#  'snippet': 'A series of winter storms unleashed heavy rain and strong winds across Portugal, Spain, France and Britain.',
#  'lead_paragraph': 'VIGO, Spain — A one-two punch of winter storms has socked Europe with strong winds and rain over several days, leaving at least nine people dead. ',
#  'print_section': 'A',
#  'print_page': '9',
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'xlarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-articleLarge.jpg',
#    'height': 400,
#    'width': 600,
#    'legacy': {'xlarge': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-articleLarge.jpg',
#     'xlargewidth': 600,
#     'xlargeheight': 400},
#    'subType': 'xlarge',
#    'crop_name': 'articleLarge'},
#   {'rank': 0,
#    'subtype': 'popup',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-popup.jpg',
#    'height': 433,
#    'width': 650,
#    'legacy': {},
#    'subType': 'popup',
#    'crop_name': 'popup'},
#   {'rank': 0,
#    'subtype': 'blog480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog480.jpg',
#    'height': 320,
#    'width': 480,
#    'legacy': {},
#    'subType': 'blog480',
#    'crop_name': 'blog480'},
#   {'rank': 0,
#    'subtype': 'blog533',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog533.jpg',
#    'height': 355,
#    'width': 533,
#    'legacy': {},
#    'subType': 'blog533',
#    'crop_name': 'blog533'},
#   {'rank': 0,
#    'subtype': 'blog427',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog427.jpg',
#    'height': 285,
#    'width': 427,
#    'legacy': {},
#    'subType': 'blog427',
#    'crop_name': 'blog427'},
#   {'rank': 0,
#    'subtype': 'tmagSF',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-tmagSF.jpg',
#    'height': 241,
#    'width': 362,
#    'legacy': {},
#    'subType': 'tmagSF',
#    'crop_name': 'tmagSF'},
#   {'rank': 0,
#    'subtype': 'tmagArticle',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-tmagArticle.jpg',
#    'height': 395,
#    'width': 592,
#    'legacy': {},
#    'subType': 'tmagArticle',
#    'crop_name': 'tmagArticle'},
#   {'rank': 0,
#    'subtype': 'slide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-slide.jpg',
#    'height': 400,
#    'width': 600,
#    'legacy': {},
#    'subType': 'slide',
#    'crop_name': 'slide'},
#   {'rank': 0,
#    'subtype': 'jumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-jumbo.jpg',
#    'height': 683,
#    'width': 1024,
#    'legacy': {},
#    'subType': 'jumbo',
#    'crop_name': 'jumbo'},
#   {'rank': 0,
#    'subtype': 'superJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-superJumbo.jpg',
#    'height': 1365,
#    'width': 2048,
#    'legacy': {},
#    'subType': 'superJumbo',
#    'crop_name': 'superJumbo'},
#   {'rank': 0,
#    'subtype': 'blog225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog225.jpg',
#    'height': 150,
#    'width': 225,
#    'legacy': {},
#    'subType': 'blog225',
#    'crop_name': 'blog225'},
#   {'rank': 0,
#    'subtype': 'master1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master1050.jpg',
#    'height': 700,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'master1050',
#    'crop_name': 'master1050'},
#   {'rank': 0,
#    'subtype': 'master675',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master675.jpg',
#    'height': 450,
#    'width': 675,
#    'legacy': {},
#    'subType': 'master675',
#    'crop_name': 'master675'},
#   {'rank': 0,
#    'subtype': 'master495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master495.jpg',
#    'height': 330,
#    'width': 495,
#    'legacy': {},
#    'subType': 'master495',
#    'crop_name': 'master495'},
#   {'rank': 0,
#    'subtype': 'master180',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master180.jpg',
#    'height': 120,
#    'width': 180,
#    'legacy': {},
#    'subType': 'master180',
#    'crop_name': 'master180'},
#   {'rank': 0,
#    'subtype': 'master315',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master315.jpg',
#    'height': 210,
#    'width': 315,
#    'legacy': {},
#    'subType': 'master315',
#    'crop_name': 'master315'},
#   {'rank': 0,
#    'subtype': 'master768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master768.jpg',
#    'height': 512,
#    'width': 768,
#    'legacy': {},
#    'subType': 'master768',
#    'crop_name': 'master768'},
#   {'rank': 0,
#    'subtype': 'thumbnail',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-thumbStandard.jpg',
#    'height': 75,
#    'width': 75,
#    'legacy': {'thumbnail': 'images/2019/12/22/world/22europe-weather/22europe-weather-thumbStandard.jpg',
#     'thumbnailwidth': 75,
#     'thumbnailheight': 75},
#    'subType': 'thumbnail',
#    'crop_name': 'thumbStandard'},
#   {'rank': 0,
#    'subtype': 'blogSmallThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-blogSmallThumb.jpg',
#    'height': 50,
#    'width': 50,
#    'legacy': {},
#    'subType': 'blogSmallThumb',
#    'crop_name': 'blogSmallThumb'},
#   {'rank': 0,
#    'subtype': 'thumbLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-thumbLarge.jpg',
#    'height': 150,
#    'width': 150,
#    'legacy': {},
#    'subType': 'thumbLarge',
#    'crop_name': 'thumbLarge'},
#   {'rank': 0,
#    'subtype': 'smallSquare168',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-smallSquare168.jpg',
#    'height': 168,
#    'width': 168,
#    'legacy': {},
#    'subType': 'smallSquare168',
#    'crop_name': 'smallSquare168'},
#   {'rank': 0,
#    'subtype': 'smallSquare252',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-smallSquare252.jpg',
#    'height': 252,
#    'width': 252,
#    'legacy': {},
#    'subType': 'smallSquare252',
#    'crop_name': 'smallSquare252'},
#   {'rank': 0,
#    'subtype': 'square320',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-square320.jpg',
#    'height': 320,
#    'width': 320,
#    'legacy': {},
#    'subType': 'square320',
#    'crop_name': 'square320'},
#   {'rank': 0,
#    'subtype': 'moth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-moth.jpg',
#    'height': 151,
#    'width': 151,
#    'legacy': {},
#    'subType': 'moth',
#    'crop_name': 'moth'},
#   {'rank': 0,
#    'subtype': 'filmstrip',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-filmstrip.jpg',
#    'height': 190,
#    'width': 190,
#    'legacy': {},
#    'subType': 'filmstrip',
#    'crop_name': 'filmstrip'},
#   {'rank': 0,
#    'subtype': 'square640',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-square640.jpg',
#    'height': 640,
#    'width': 640,
#    'legacy': {},
#    'subType': 'square640',
#    'crop_name': 'square640'},
#   {'rank': 0,
#    'subtype': 'mediumSquare149',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-mediumSquare149.jpg',
#    'height': 149,
#    'width': 149,
#    'legacy': {},
#    'subType': 'mediumSquare149',
#    'crop_name': 'mediumSquare149'},
#   {'rank': 0,
#    'subtype': 'sfSpan',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-sfSpan.jpg',
#    'height': 263,
#    'width': 395,
#    'legacy': {},
#    'subType': 'sfSpan',
#    'crop_name': 'sfSpan'},
#   {'rank': 0,
#    'subtype': 'largeHorizontal375',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-largeHorizontal375.jpg',
#    'height': 250,
#    'width': 375,
#    'legacy': {},
#    'subType': 'largeHorizontal375',
#    'crop_name': 'largeHorizontal375'},
#   {'rank': 0,
#    'subtype': 'largeHorizontalJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-largeHorizontalJumbo.jpg',
#    'height': 683,
#    'width': 1024,
#    'legacy': {},
#    'subType': 'largeHorizontalJumbo',
#    'crop_name': 'largeHorizontalJumbo'},
#   {'rank': 0,
#    'subtype': 'horizontalMediumAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-horizontalMediumAt2X.jpg',
#    'height': 3094,
#    'width': 4641,
#    'legacy': {},
#    'subType': 'horizontalMediumAt2X',
#    'crop_name': 'horizontalMediumAt2X'},
#   {'rank': 0,
#    'subtype': 'hpLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-hpLarge.jpg',
#    'height': 287,
#    'width': 511,
#    'legacy': {},
#    'subType': 'hpLarge',
#    'crop_name': 'hpLarge'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen573',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-largeWidescreen573.jpg',
#    'height': 322,
#    'width': 573,
#    'legacy': {},
#    'subType': 'largeWidescreen573',
#    'crop_name': 'largeWidescreen573'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-largeWidescreen1050.jpg',
#    'height': 591,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'largeWidescreen1050',
#    'crop_name': 'largeWidescreen1050'},
#   {'rank': 0,
#    'subtype': 'wide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-thumbWide.jpg',
#    'height': 126,
#    'width': 190,
#    'legacy': {'widewidth': 190,
#     'wideheight': 126,
#     'wide': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-thumbWide.jpg'},
#    'subType': 'wide',
#    'crop_name': 'thumbWide'},
#   {'rank': 0,
#    'subtype': 'videoThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-videoThumb.jpg',
#    'height': 50,
#    'width': 75,
#    'legacy': {},
#    'subType': 'videoThumb',
#    'crop_name': 'videoThumb'},
#   {'rank': 0,
#    'subtype': 'videoLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-videoLarge.jpg',
#    'height': 507,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoLarge',
#    'crop_name': 'videoLarge'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo210',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo210.jpg',
#    'height': 140,
#    'width': 210,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo210',
#    'crop_name': 'mediumThreeByTwo210'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo225.jpg',
#    'height': 150,
#    'width': 225,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo225',
#    'crop_name': 'mediumThreeByTwo225'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo440',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo440.jpg',
#    'height': 293,
#    'width': 440,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo440',
#    'crop_name': 'mediumThreeByTwo440'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo252',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo252.jpg',
#    'height': 168,
#    'width': 252,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo252',
#    'crop_name': 'mediumThreeByTwo252'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo378',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo378.jpg',
#    'height': 252,
#    'width': 378,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo378',
#    'crop_name': 'mediumThreeByTwo378'},
#   {'rank': 0,
#    'subtype': 'threeByTwoLargeAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-threeByTwoLargeAt2X.jpg',
#    'height': 3094,
#    'width': 4641,
#    'legacy': {},
#    'subType': 'threeByTwoLargeAt2X',
#    'crop_name': 'threeByTwoLargeAt2X'},
#   {'rank': 0,
#    'subtype': 'threeByTwoMediumAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-threeByTwoMediumAt2X.jpg',
#    'height': 1000,
#    'width': 1500,
#    'legacy': {},
#    'subType': 'threeByTwoMediumAt2X',
#    'crop_name': 'threeByTwoMediumAt2X'},
#   {'rank': 0,
#    'subtype': 'threeByTwoSmallAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-threeByTwoSmallAt2X.jpg',
#    'height': 400,
#    'width': 600,
#    'legacy': {},
#    'subType': 'threeByTwoSmallAt2X',
#    'crop_name': 'threeByTwoSmallAt2X'},
#   {'rank': 0,
#    'subtype': 'articleInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-articleInline.jpg',
#    'height': 127,
#    'width': 190,
#    'legacy': {},
#    'subType': 'articleInline',
#    'crop_name': 'articleInline'},
#   {'rank': 0,
#    'subtype': 'hpSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-hpSmall.jpg',
#    'height': 109,
#    'width': 163,
#    'legacy': {},
#    'subType': 'hpSmall',
#    'crop_name': 'hpSmall'},
#   {'rank': 0,
#    'subtype': 'blogSmallInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blogSmallInline.jpg',
#    'height': 101,
#    'width': 151,
#    'legacy': {},
#    'subType': 'blogSmallInline',
#    'crop_name': 'blogSmallInline'},
#   {'rank': 0,
#    'subtype': 'mediumFlexible177',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumFlexible177.jpg',
#    'height': 118,
#    'width': 177,
#    'legacy': {},
#    'subType': 'mediumFlexible177',
#    'crop_name': 'mediumFlexible177'},
#   {'rank': 0,
#    'subtype': 'videoSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSmall.jpg',
#    'height': 281,
#    'width': 500,
#    'legacy': {},
#    'subType': 'videoSmall',
#    'crop_name': 'videoSmall'},
#   {'rank': 0,
#    'subtype': 'videoHpMedium',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoHpMedium.jpg',
#    'height': 211,
#    'width': 375,
#    'legacy': {},
#    'subType': 'videoHpMedium',
#    'crop_name': 'videoHpMedium'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine600.jpg',
#    'height': 338,
#    'width': 600,
#    'legacy': {},
#    'subType': 'videoSixteenByNine600',
#    'crop_name': 'videoSixteenByNine600'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine540',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine540.jpg',
#    'height': 304,
#    'width': 540,
#    'legacy': {},
#    'subType': 'videoSixteenByNine540',
#    'crop_name': 'videoSixteenByNine540'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine495.jpg',
#    'height': 278,
#    'width': 495,
#    'legacy': {},
#    'subType': 'videoSixteenByNine495',
#    'crop_name': 'videoSixteenByNine495'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine390',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine390.jpg',
#    'height': 219,
#    'width': 390,
#    'legacy': {},
#    'subType': 'videoSixteenByNine390',
#    'crop_name': 'videoSixteenByNine390'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine1050.jpg',
#    'height': 591,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'videoSixteenByNine1050',
#    'crop_name': 'videoSixteenByNine1050'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine480.jpg',
#    'height': 270,
#    'width': 480,
#    'legacy': {},
#    'subType': 'videoSixteenByNine480',
#    'crop_name': 'videoSixteenByNine480'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine310',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine310.jpg',
#    'height': 174,
#    'width': 310,
#    'legacy': {},
#    'subType': 'videoSixteenByNine310',
#    'crop_name': 'videoSixteenByNine310'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine225.jpg',
#    'height': 126,
#    'width': 225,
#    'legacy': {},
#    'subType': 'videoSixteenByNine225',
#    'crop_name': 'videoSixteenByNine225'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine96',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine96.jpg',
#    'height': 54,
#    'width': 96,
#    'legacy': {},
#    'subType': 'videoSixteenByNine96',
#    'crop_name': 'videoSixteenByNine96'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine3000',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine3000.jpg',
#    'height': 1688,
#    'width': 3000,
#    'legacy': {},
#    'subType': 'videoSixteenByNine3000',
#    'crop_name': 'videoSixteenByNine3000'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine768.jpg',
#    'height': 432,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoSixteenByNine768',
#    'crop_name': 'videoSixteenByNine768'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine150',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine150.jpg',
#    'height': 84,
#    'width': 150,
#    'legacy': {},
#    'subType': 'videoSixteenByNine150',
#    'crop_name': 'videoSixteenByNine150'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNineJumbo1600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNineJumbo1600.jpg',
#    'height': 900,
#    'width': 1600,
#    'legacy': {},
#    'subType': 'videoSixteenByNineJumbo1600',
#    'crop_name': 'videoSixteenByNineJumbo1600'},
#   {'rank': 0,
#    'subtype': 'miniMoth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-miniMoth.jpg',
#    'height': 70,
#    'width': 151,
#    'legacy': {},
#    'subType': 'miniMoth',
#    'crop_name': 'miniMoth'},
#   {'rank': 0,
#    'subtype': 'windowsTile336H',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-windowsTile336H.jpg',
#    'height': 336,
#    'width': 694,
#    'legacy': {},
#    'subType': 'windowsTile336H',
#    'crop_name': 'windowsTile336H'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven1305',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoFifteenBySeven1305.jpg',
#    'height': 609,
#    'width': 1305,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven1305',
#    'crop_name': 'videoFifteenBySeven1305'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven2610',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoFifteenBySeven2610.jpg',
#    'height': 1218,
#    'width': 2610,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven2610',
#    'crop_name': 'videoFifteenBySeven2610'},
#   {'rank': 0,
#    'subtype': 'facebookJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-facebookJumbo.jpg',
#    'height': 550,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'facebookJumbo',
#    'crop_name': 'facebookJumbo'},
#   {'rank': 0,
#    'subtype': 'watch308',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-watch308.jpg',
#    'height': 348,
#    'width': 312,
#    'legacy': {},
#    'subType': 'watch308',
#    'crop_name': 'watch308'},
#   {'rank': 0,
#    'subtype': 'watch268',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-watch268.jpg',
#    'height': 303,
#    'width': 272,
#    'legacy': {},
#    'subType': 'watch268',
#    'crop_name': 'watch268'},
#   {'rank': 0,
#    'subtype': 'verticalTwoByThree735',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-verticalTwoByThree735.jpg',
#    'height': 1102,
#    'width': 735,
#    'legacy': {},
#    'subType': 'verticalTwoByThree735',
#    'crop_name': 'verticalTwoByThree735'},
#   {'rank': 0,
#    'subtype': 'mobileMasterAt3x',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mobileMasterAt3x.jpg',
#    'height': 1200,
#    'width': 1800,
#    'legacy': {},
#    'subType': 'mobileMasterAt3x',
#    'crop_name': 'mobileMasterAt3x'}],
#  'headline': {'main': 'Severe Weather Across Europe Leaves at Least 9 Dead',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': '9 Are Dead as Winter Storms Rock Europe',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject', 'value': 'Weather', 'rank': 1, 'major': 'N'},
#   {'name': 'subject', 'value': 'Wind', 'rank': 2, 'major': 'N'},
#   {'name': 'subject', 'value': 'Floods', 'rank': 3, 'major': 'N'},
#   {'name': 'subject', 'value': 'Deaths (Fatalities)', 'rank': 4, 'major': 'N'},
#   {'name': 'subject', 'value': 'Rain', 'rank': 5, 'major': 'N'},
#   {'name': 'subject', 'value': 'Tornadoes', 'rank': 6, 'major': 'N'},
#   {'name': 'glocations', 'value': 'France', 'rank': 7, 'major': 'N'},
#   {'name': 'glocations', 'value': 'Great Britain', 'rank': 8, 'major': 'N'},
#   {'name': 'glocations', 'value': 'Portugal', 'rank': 9, 'major': 'N'},
#   {'name': 'glocations', 'value': 'Spain', 'rank': 10, 'major': 'N'}],
#  'pub_date': '2019-12-22T18:43:45+0000',
#  'document_type': 'article',
#  'news_desk': 'Foreign',
#  'section_name': 'World',
#  'subsection_name': 'Europe',
#  'byline': {'original': 'By Raphael Minder and Iliana Magra',
#   'person': [{'firstname': 'Raphael',
#     'middlename': None,
#     'lastname': 'Minder',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1},
#    {'firstname': 'Iliana',
#     'middlename': None,
#     'lastname': 'Magra',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 2}],
#   'organization': None},
#  'type_of_material': 'News',
#  '_id': 'nyt://article/2c62a6b7-1996-58cd-8a74-bd6f3f2a0c69',
#  'word_count': 523,
#  'uri': 'nyt://article/2c62a6b7-1996-58cd-8a74-bd6f3f2a0c69'}

# %%
res.json()['response']['docs'][0]['multimedia']
# Out:
# [{'rank': 0,
#   'subtype': 'xlarge',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-articleLarge.jpg',
#   'height': 400,
#   'width': 600,
#   'legacy': {'xlarge': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-articleLarge.jpg',
#    'xlargewidth': 600,
#    'xlargeheight': 400},
#   'subType': 'xlarge',
#   'crop_name': 'articleLarge'},
#  {'rank': 0,
#   'subtype': 'popup',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-popup.jpg',
#   'height': 433,
#   'width': 650,
#   'legacy': {},
#   'subType': 'popup',
#   'crop_name': 'popup'},
#  {'rank': 0,
#   'subtype': 'blog480',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog480.jpg',
#   'height': 320,
#   'width': 480,
#   'legacy': {},
#   'subType': 'blog480',
#   'crop_name': 'blog480'},
#  {'rank': 0,
#   'subtype': 'blog533',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog533.jpg',
#   'height': 355,
#   'width': 533,
#   'legacy': {},
#   'subType': 'blog533',
#   'crop_name': 'blog533'},
#  {'rank': 0,
#   'subtype': 'blog427',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog427.jpg',
#   'height': 285,
#   'width': 427,
#   'legacy': {},
#   'subType': 'blog427',
#   'crop_name': 'blog427'},
#  {'rank': 0,
#   'subtype': 'tmagSF',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-tmagSF.jpg',
#   'height': 241,
#   'width': 362,
#   'legacy': {},
#   'subType': 'tmagSF',
#   'crop_name': 'tmagSF'},
#  {'rank': 0,
#   'subtype': 'tmagArticle',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-tmagArticle.jpg',
#   'height': 395,
#   'width': 592,
#   'legacy': {},
#   'subType': 'tmagArticle',
#   'crop_name': 'tmagArticle'},
#  {'rank': 0,
#   'subtype': 'slide',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-slide.jpg',
#   'height': 400,
#   'width': 600,
#   'legacy': {},
#   'subType': 'slide',
#   'crop_name': 'slide'},
#  {'rank': 0,
#   'subtype': 'jumbo',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-jumbo.jpg',
#   'height': 683,
#   'width': 1024,
#   'legacy': {},
#   'subType': 'jumbo',
#   'crop_name': 'jumbo'},
#  {'rank': 0,
#   'subtype': 'superJumbo',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-superJumbo.jpg',
#   'height': 1365,
#   'width': 2048,
#   'legacy': {},
#   'subType': 'superJumbo',
#   'crop_name': 'superJumbo'},
#  {'rank': 0,
#   'subtype': 'blog225',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blog225.jpg',
#   'height': 150,
#   'width': 225,
#   'legacy': {},
#   'subType': 'blog225',
#   'crop_name': 'blog225'},
#  {'rank': 0,
#   'subtype': 'master1050',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master1050.jpg',
#   'height': 700,
#   'width': 1050,
#   'legacy': {},
#   'subType': 'master1050',
#   'crop_name': 'master1050'},
#  {'rank': 0,
#   'subtype': 'master675',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master675.jpg',
#   'height': 450,
#   'width': 675,
#   'legacy': {},
#   'subType': 'master675',
#   'crop_name': 'master675'},
#  {'rank': 0,
#   'subtype': 'master495',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master495.jpg',
#   'height': 330,
#   'width': 495,
#   'legacy': {},
#   'subType': 'master495',
#   'crop_name': 'master495'},
#  {'rank': 0,
#   'subtype': 'master180',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master180.jpg',
#   'height': 120,
#   'width': 180,
#   'legacy': {},
#   'subType': 'master180',
#   'crop_name': 'master180'},
#  {'rank': 0,
#   'subtype': 'master315',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master315.jpg',
#   'height': 210,
#   'width': 315,
#   'legacy': {},
#   'subType': 'master315',
#   'crop_name': 'master315'},
#  {'rank': 0,
#   'subtype': 'master768',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master768.jpg',
#   'height': 512,
#   'width': 768,
#   'legacy': {},
#   'subType': 'master768',
#   'crop_name': 'master768'},
#  {'rank': 0,
#   'subtype': 'thumbnail',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-thumbStandard.jpg',
#   'height': 75,
#   'width': 75,
#   'legacy': {'thumbnail': 'images/2019/12/22/world/22europe-weather/22europe-weather-thumbStandard.jpg',
#    'thumbnailwidth': 75,
#    'thumbnailheight': 75},
#   'subType': 'thumbnail',
#   'crop_name': 'thumbStandard'},
#  {'rank': 0,
#   'subtype': 'blogSmallThumb',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-blogSmallThumb.jpg',
#   'height': 50,
#   'width': 50,
#   'legacy': {},
#   'subType': 'blogSmallThumb',
#   'crop_name': 'blogSmallThumb'},
#  {'rank': 0,
#   'subtype': 'thumbLarge',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-thumbLarge.jpg',
#   'height': 150,
#   'width': 150,
#   'legacy': {},
#   'subType': 'thumbLarge',
#   'crop_name': 'thumbLarge'},
#  {'rank': 0,
#   'subtype': 'smallSquare168',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-smallSquare168.jpg',
#   'height': 168,
#   'width': 168,
#   'legacy': {},
#   'subType': 'smallSquare168',
#   'crop_name': 'smallSquare168'},
#  {'rank': 0,
#   'subtype': 'smallSquare252',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-smallSquare252.jpg',
#   'height': 252,
#   'width': 252,
#   'legacy': {},
#   'subType': 'smallSquare252',
#   'crop_name': 'smallSquare252'},
#  {'rank': 0,
#   'subtype': 'square320',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-square320.jpg',
#   'height': 320,
#   'width': 320,
#   'legacy': {},
#   'subType': 'square320',
#   'crop_name': 'square320'},
#  {'rank': 0,
#   'subtype': 'moth',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-moth.jpg',
#   'height': 151,
#   'width': 151,
#   'legacy': {},
#   'subType': 'moth',
#   'crop_name': 'moth'},
#  {'rank': 0,
#   'subtype': 'filmstrip',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-filmstrip.jpg',
#   'height': 190,
#   'width': 190,
#   'legacy': {},
#   'subType': 'filmstrip',
#   'crop_name': 'filmstrip'},
#  {'rank': 0,
#   'subtype': 'square640',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-square640.jpg',
#   'height': 640,
#   'width': 640,
#   'legacy': {},
#   'subType': 'square640',
#   'crop_name': 'square640'},
#  {'rank': 0,
#   'subtype': 'mediumSquare149',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-mediumSquare149.jpg',
#   'height': 149,
#   'width': 149,
#   'legacy': {},
#   'subType': 'mediumSquare149',
#   'crop_name': 'mediumSquare149'},
#  {'rank': 0,
#   'subtype': 'sfSpan',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-sfSpan.jpg',
#   'height': 263,
#   'width': 395,
#   'legacy': {},
#   'subType': 'sfSpan',
#   'crop_name': 'sfSpan'},
#  {'rank': 0,
#   'subtype': 'largeHorizontal375',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-largeHorizontal375.jpg',
#   'height': 250,
#   'width': 375,
#   'legacy': {},
#   'subType': 'largeHorizontal375',
#   'crop_name': 'largeHorizontal375'},
#  {'rank': 0,
#   'subtype': 'largeHorizontalJumbo',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-largeHorizontalJumbo.jpg',
#   'height': 683,
#   'width': 1024,
#   'legacy': {},
#   'subType': 'largeHorizontalJumbo',
#   'crop_name': 'largeHorizontalJumbo'},
#  {'rank': 0,
#   'subtype': 'horizontalMediumAt2X',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-horizontalMediumAt2X.jpg',
#   'height': 3094,
#   'width': 4641,
#   'legacy': {},
#   'subType': 'horizontalMediumAt2X',
#   'crop_name': 'horizontalMediumAt2X'},
#  {'rank': 0,
#   'subtype': 'hpLarge',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-hpLarge.jpg',
#   'height': 287,
#   'width': 511,
#   'legacy': {},
#   'subType': 'hpLarge',
#   'crop_name': 'hpLarge'},
#  {'rank': 0,
#   'subtype': 'largeWidescreen573',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-largeWidescreen573.jpg',
#   'height': 322,
#   'width': 573,
#   'legacy': {},
#   'subType': 'largeWidescreen573',
#   'crop_name': 'largeWidescreen573'},
#  {'rank': 0,
#   'subtype': 'largeWidescreen1050',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-largeWidescreen1050.jpg',
#   'height': 591,
#   'width': 1050,
#   'legacy': {},
#   'subType': 'largeWidescreen1050',
#   'crop_name': 'largeWidescreen1050'},
#  {'rank': 0,
#   'subtype': 'wide',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-thumbWide.jpg',
#   'height': 126,
#   'width': 190,
#   'legacy': {'widewidth': 190,
#    'wideheight': 126,
#    'wide': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-thumbWide.jpg'},
#   'subType': 'wide',
#   'crop_name': 'thumbWide'},
#  {'rank': 0,
#   'subtype': 'videoThumb',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-videoThumb.jpg',
#   'height': 50,
#   'width': 75,
#   'legacy': {},
#   'subType': 'videoThumb',
#   'crop_name': 'videoThumb'},
#  {'rank': 0,
#   'subtype': 'videoLarge',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-videoLarge.jpg',
#   'height': 507,
#   'width': 768,
#   'legacy': {},
#   'subType': 'videoLarge',
#   'crop_name': 'videoLarge'},
#  {'rank': 0,
#   'subtype': 'mediumThreeByTwo210',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo210.jpg',
#   'height': 140,
#   'width': 210,
#   'legacy': {},
#   'subType': 'mediumThreeByTwo210',
#   'crop_name': 'mediumThreeByTwo210'},
#  {'rank': 0,
#   'subtype': 'mediumThreeByTwo225',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo225.jpg',
#   'height': 150,
#   'width': 225,
#   'legacy': {},
#   'subType': 'mediumThreeByTwo225',
#   'crop_name': 'mediumThreeByTwo225'},
#  {'rank': 0,
#   'subtype': 'mediumThreeByTwo440',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo440.jpg',
#   'height': 293,
#   'width': 440,
#   'legacy': {},
#   'subType': 'mediumThreeByTwo440',
#   'crop_name': 'mediumThreeByTwo440'},
#  {'rank': 0,
#   'subtype': 'mediumThreeByTwo252',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo252.jpg',
#   'height': 168,
#   'width': 252,
#   'legacy': {},
#   'subType': 'mediumThreeByTwo252',
#   'crop_name': 'mediumThreeByTwo252'},
#  {'rank': 0,
#   'subtype': 'mediumThreeByTwo378',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumThreeByTwo378.jpg',
#   'height': 252,
#   'width': 378,
#   'legacy': {},
#   'subType': 'mediumThreeByTwo378',
#   'crop_name': 'mediumThreeByTwo378'},
#  {'rank': 0,
#   'subtype': 'threeByTwoLargeAt2X',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-threeByTwoLargeAt2X.jpg',
#   'height': 3094,
#   'width': 4641,
#   'legacy': {},
#   'subType': 'threeByTwoLargeAt2X',
#   'crop_name': 'threeByTwoLargeAt2X'},
#  {'rank': 0,
#   'subtype': 'threeByTwoMediumAt2X',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-threeByTwoMediumAt2X.jpg',
#   'height': 1000,
#   'width': 1500,
#   'legacy': {},
#   'subType': 'threeByTwoMediumAt2X',
#   'crop_name': 'threeByTwoMediumAt2X'},
#  {'rank': 0,
#   'subtype': 'threeByTwoSmallAt2X',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-threeByTwoSmallAt2X.jpg',
#   'height': 400,
#   'width': 600,
#   'legacy': {},
#   'subType': 'threeByTwoSmallAt2X',
#   'crop_name': 'threeByTwoSmallAt2X'},
#  {'rank': 0,
#   'subtype': 'articleInline',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-articleInline.jpg',
#   'height': 127,
#   'width': 190,
#   'legacy': {},
#   'subType': 'articleInline',
#   'crop_name': 'articleInline'},
#  {'rank': 0,
#   'subtype': 'hpSmall',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-hpSmall.jpg',
#   'height': 109,
#   'width': 163,
#   'legacy': {},
#   'subType': 'hpSmall',
#   'crop_name': 'hpSmall'},
#  {'rank': 0,
#   'subtype': 'blogSmallInline',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-blogSmallInline.jpg',
#   'height': 101,
#   'width': 151,
#   'legacy': {},
#   'subType': 'blogSmallInline',
#   'crop_name': 'blogSmallInline'},
#  {'rank': 0,
#   'subtype': 'mediumFlexible177',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mediumFlexible177.jpg',
#   'height': 118,
#   'width': 177,
#   'legacy': {},
#   'subType': 'mediumFlexible177',
#   'crop_name': 'mediumFlexible177'},
#  {'rank': 0,
#   'subtype': 'videoSmall',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSmall.jpg',
#   'height': 281,
#   'width': 500,
#   'legacy': {},
#   'subType': 'videoSmall',
#   'crop_name': 'videoSmall'},
#  {'rank': 0,
#   'subtype': 'videoHpMedium',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoHpMedium.jpg',
#   'height': 211,
#   'width': 375,
#   'legacy': {},
#   'subType': 'videoHpMedium',
#   'crop_name': 'videoHpMedium'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine600',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine600.jpg',
#   'height': 338,
#   'width': 600,
#   'legacy': {},
#   'subType': 'videoSixteenByNine600',
#   'crop_name': 'videoSixteenByNine600'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine540',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine540.jpg',
#   'height': 304,
#   'width': 540,
#   'legacy': {},
#   'subType': 'videoSixteenByNine540',
#   'crop_name': 'videoSixteenByNine540'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine495',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine495.jpg',
#   'height': 278,
#   'width': 495,
#   'legacy': {},
#   'subType': 'videoSixteenByNine495',
#   'crop_name': 'videoSixteenByNine495'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine390',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine390.jpg',
#   'height': 219,
#   'width': 390,
#   'legacy': {},
#   'subType': 'videoSixteenByNine390',
#   'crop_name': 'videoSixteenByNine390'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine1050',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine1050.jpg',
#   'height': 591,
#   'width': 1050,
#   'legacy': {},
#   'subType': 'videoSixteenByNine1050',
#   'crop_name': 'videoSixteenByNine1050'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine480',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine480.jpg',
#   'height': 270,
#   'width': 480,
#   'legacy': {},
#   'subType': 'videoSixteenByNine480',
#   'crop_name': 'videoSixteenByNine480'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine310',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine310.jpg',
#   'height': 174,
#   'width': 310,
#   'legacy': {},
#   'subType': 'videoSixteenByNine310',
#   'crop_name': 'videoSixteenByNine310'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine225',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine225.jpg',
#   'height': 126,
#   'width': 225,
#   'legacy': {},
#   'subType': 'videoSixteenByNine225',
#   'crop_name': 'videoSixteenByNine225'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine96',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine96.jpg',
#   'height': 54,
#   'width': 96,
#   'legacy': {},
#   'subType': 'videoSixteenByNine96',
#   'crop_name': 'videoSixteenByNine96'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine3000',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine3000.jpg',
#   'height': 1688,
#   'width': 3000,
#   'legacy': {},
#   'subType': 'videoSixteenByNine3000',
#   'crop_name': 'videoSixteenByNine3000'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine768',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine768.jpg',
#   'height': 432,
#   'width': 768,
#   'legacy': {},
#   'subType': 'videoSixteenByNine768',
#   'crop_name': 'videoSixteenByNine768'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNine150',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNine150.jpg',
#   'height': 84,
#   'width': 150,
#   'legacy': {},
#   'subType': 'videoSixteenByNine150',
#   'crop_name': 'videoSixteenByNine150'},
#  {'rank': 0,
#   'subtype': 'videoSixteenByNineJumbo1600',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoSixteenByNineJumbo1600.jpg',
#   'height': 900,
#   'width': 1600,
#   'legacy': {},
#   'subType': 'videoSixteenByNineJumbo1600',
#   'crop_name': 'videoSixteenByNineJumbo1600'},
#  {'rank': 0,
#   'subtype': 'miniMoth',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-miniMoth.jpg',
#   'height': 70,
#   'width': 151,
#   'legacy': {},
#   'subType': 'miniMoth',
#   'crop_name': 'miniMoth'},
#  {'rank': 0,
#   'subtype': 'windowsTile336H',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-windowsTile336H.jpg',
#   'height': 336,
#   'width': 694,
#   'legacy': {},
#   'subType': 'windowsTile336H',
#   'crop_name': 'windowsTile336H'},
#  {'rank': 0,
#   'subtype': 'videoFifteenBySeven1305',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoFifteenBySeven1305.jpg',
#   'height': 609,
#   'width': 1305,
#   'legacy': {},
#   'subType': 'videoFifteenBySeven1305',
#   'crop_name': 'videoFifteenBySeven1305'},
#  {'rank': 0,
#   'subtype': 'videoFifteenBySeven2610',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-videoFifteenBySeven2610.jpg',
#   'height': 1218,
#   'width': 2610,
#   'legacy': {},
#   'subType': 'videoFifteenBySeven2610',
#   'crop_name': 'videoFifteenBySeven2610'},
#  {'rank': 0,
#   'subtype': 'facebookJumbo',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-facebookJumbo.jpg',
#   'height': 550,
#   'width': 1050,
#   'legacy': {},
#   'subType': 'facebookJumbo',
#   'crop_name': 'facebookJumbo'},
#  {'rank': 0,
#   'subtype': 'watch308',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-watch308.jpg',
#   'height': 348,
#   'width': 312,
#   'legacy': {},
#   'subType': 'watch308',
#   'crop_name': 'watch308'},
#  {'rank': 0,
#   'subtype': 'watch268',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-watch268.jpg',
#   'height': 303,
#   'width': 272,
#   'legacy': {},
#   'subType': 'watch268',
#   'crop_name': 'watch268'},
#  {'rank': 0,
#   'subtype': 'verticalTwoByThree735',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/22europe-weather-verticalTwoByThree735.jpg',
#   'height': 1102,
#   'width': 735,
#   'legacy': {},
#   'subType': 'verticalTwoByThree735',
#   'crop_name': 'verticalTwoByThree735'},
#  {'rank': 0,
#   'subtype': 'mobileMasterAt3x',
#   'caption': None,
#   'credit': None,
#   'type': 'image',
#   'url': 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-mobileMasterAt3x.jpg',
#   'height': 1200,
#   'width': 1800,
#   'legacy': {},
#   'subType': 'mobileMasterAt3x',
#   'crop_name': 'mobileMasterAt3x'}]

# %% [markdown]
# ### Function to query articles
# with subject "Floods"

# %%
# pub_date, multimedia, width, height, ['headline']['main'], web_url
def get_nyt_api_articles(begin_date, end_date, page, key):
    
    url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
    res = requests.get(
        url,
        params = {
            'begin_date': begin_date,
            'end_date': end_date,
            'sort': 'newest',
            'page': page,

            'type': 'article',
            'q': 'flood',
            'fq': 'subject:("Floods")',
            'api-key': key
        }
    )
    assert res.status_code == 200
    
    pub_date_list = []
    width_list = []
    height_list = []
    image_url_list = []
    headline_list = []
    web_url_list = []
    for document in res.json()['response']['docs']:
        headline = document['headline']['main']
        web_url = document['web_url']
        pub_date = pd.to_datetime(document['pub_date'])
        
        for image in document['multimedia']:
            if image['crop_name'] == 'master675': # master version of image
                pub_date_list.append(pub_date)
                width_list.append(int(image['width']))
                height_list.append(int(image['height']))
                image_url_list.append(image['url'])
                headline_list.append(headline)
                web_url_list.append(web_url)
    
    return pd.DataFrame(
        data = {
            'pub_date': pub_date_list,
            'width': width_list,
            'height': height_list,
            'image_url': image_url_list,
            'headline': headline_list,
            'web_url': web_url_list
        }
    )

# %%
df = get_nyt_api_articles(
    begin_date = '20120101',
    end_date = '20200101',
    page = 0,
    key = apikey
)

# %%
df.dtypes
# Out:
# pub_date     object
# width         int64
# height        int64
# image_url    object
# headline     object
# web_url      object
# dtype: object

# %%
df
# Out:
#                      pub_date  width  height  \
# 0    2019-12-22T18:43:45+0000    600     400
# 1    2019-12-22T18:43:45+0000    650     433
# 2    2019-12-22T18:43:45+0000    480     320
# 3    2019-12-22T18:43:45+0000    533     355
# 4    2019-12-22T18:43:45+0000    427     285
# ..                        ...    ...     ...
# 652  2019-11-21T10:00:28+0000   1050     550
# 653  2019-11-21T10:00:28+0000    312     348
# 654  2019-11-21T10:00:28+0000    272     303
# 655  2019-11-21T10:00:28+0000    735    1103
# 656  2019-11-21T10:00:28+0000   1800    1200
#
#                                              image_url  \
# 0    images/2019/12/22/world/22europe-weather/merli...
# 1    images/2019/12/22/world/22europe-weather/merli...
# 2    images/2019/12/22/world/22europe-weather/merli...
# 3    images/2019/12/22/world/22europe-weather/merli...
# 4    images/2019/12/22/world/22europe-weather/merli...
# ..                                                 ...
# 652  images/2019/11/22/climate/00CLI-AGRICULTURE-pr...
# 653  images/2019/11/22/climate/00CLI-AGRICULTURE-pr...
# 654  images/2019/11/22/climate/00CLI-AGRICULTURE-pr...
# 655  images/2019/11/22/climate/00CLI-AGRICULTURE-pr...
# 656  images/2019/11/22/climate/00CLI-AGRICULTURE-pr...
#
#                                               headline  \
# 0    Severe Weather Across Europe Leaves at Least 9...
# 1    Severe Weather Across Europe Leaves at Least 9...
# 2    Severe Weather Across Europe Leaves at Least 9...
# 3    Severe Weather Across Europe Leaves at Least 9...
# 4    Severe Weather Across Europe Leaves at Least 9...
# ..                                                 ...
# 652  A Wet Year Causes Farm Woes Far Beyond the Flo...
# 653  A Wet Year Causes Farm Woes Far Beyond the Flo...
# 654  A Wet Year Causes Farm Woes Far Beyond the Flo...
# 655  A Wet Year Causes Farm Woes Far Beyond the Flo...
# 656  A Wet Year Causes Farm Woes Far Beyond the Flo...
#
#                                                web_url
# 0    https://www.nytimes.com/2019/12/22/world/europ...
# 1    https://www.nytimes.com/2019/12/22/world/europ...
# 2    https://www.nytimes.com/2019/12/22/world/europ...
# 3    https://www.nytimes.com/2019/12/22/world/europ...
# 4    https://www.nytimes.com/2019/12/22/world/europ...
# ..                                                 ...
# 652  https://www.nytimes.com/2019/11/21/climate/far...
# 653  https://www.nytimes.com/2019/11/21/climate/far...
# 654  https://www.nytimes.com/2019/11/21/climate/far...
# 655  https://www.nytimes.com/2019/11/21/climate/far...
# 656  https://www.nytimes.com/2019/11/21/climate/far...
#
# [657 rows x 6 columns]

# %% [markdown]
# ### Get all 1000 items returned by query

# %%
def get_nyt_api_images(begin_date_, end_date_):
    start_time = time.time()
    
    print(f'Beginning requests for date range {begin_date_}-{end_date_}.')
    
    df_list = []
    for i in range(0, 100):
        if i % 10 == 0:
            print(f'Sending request {i} at time {round(time.time() - start_time)} s...')

        df_list.append(get_nyt_api_articles(
            begin_date = begin_date_,
            end_date = end_date_,
            page = i,
            key = apikey
        ))

        time.sleep(12) # never < 6

    print(f'Image links received. Took {round(time.time() - start_time)} s.')
    df = pd.concat(df_list)
    df.reset_index(drop=True, inplace=True)
    
    return df

# %% [markdown]
# ### Get 1000 items from several different date ranges

# %% [markdown]
# each of which has ~1000 hits

# %%
def get_n_hits(begin_date, end_date):
    url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
    res = requests.get(
        url,
        params = {
            'begin_date': begin_date,
            'end_date': end_date,

            'sort': 'newest',
            'page': '0',
            'type': 'article',
            'q': 'flood',
            'fq': 'subject:("Floods")',
            'api-key': apikey
        }
    )
    assert res.status_code == 200
    print(f'{begin_date}-{end_date}', res.json()['response']['meta'])

# %%
get_n_hits('20120101', '20200101')
# Out:
# 20120101-20200101 {'hits': 1022, 'offset': 0, 'time': 145}

# %%
get_n_hits('20040101', '20120101')
# Out:
# 20040101-20120101 {'hits': 1042, 'offset': 0, 'time': 89}

# %%
get_n_hits('19900101', '20040101')
# Out:
# 19900101-20040101 {'hits': 1026, 'offset': 0, 'time': 252}

# %%
get_n_hits('19770101', '19900101')
# Out:
# 19770101-19900101 {'hits': 1052, 'offset': 0, 'time': 109}

# %%
get_n_hits('19700101', '19770101')
# Out:
# 19700101-19770101 {'hits': 1044, 'offset': 0, 'time': 187}

# %%
df_list = []

# %%
df_list.append(get_nyt_api_images('20120101', '20200101'))
# Out:
# Beginning requests for date range 20120101-20200101.
# Sending request 0 at time 0 s...
# Sending request 10 at time 114 s...
# Sending request 20 at time 226 s...
# Sending request 30 at time 340 s...
# Sending request 40 at time 453 s...
# Sending request 50 at time 566 s...
# Sending request 60 at time 681 s...
# Sending request 70 at time 793 s...
# Sending request 80 at time 906 s...
# Sending request 90 at time 1017 s...
# Sending request 100 at time 1127 s...
# Image links received. Took 1138 s.

# %%
df_list[0]
# Out:
#                       pub_date  width  height  \
# 0    2019-12-22 18:43:45+00:00  675.0   450.0
# 1    2019-12-19 10:00:24+00:00  675.0   450.0
# 2    2019-12-18 10:04:31+00:00  675.0   420.0
# 3    2019-12-04 17:55:29+00:00  675.0   450.0
# 4    2019-12-03 07:37:28+00:00  675.0   450.0
# ..                         ...    ...     ...
# 653  2013-05-29 23:47:51+00:00  675.0   450.0
# 654  2013-05-28 23:30:58+00:00  675.0   450.0
# 655  2013-05-11 00:46:19+00:00  675.0   416.0
# 656  2012-10-31 01:35:07+00:00  675.0   481.0
# 657  2012-10-28 14:14:53+00:00  675.0   449.0
#
#                                              image_url  \
# 0    images/2019/12/22/world/22europe-weather/merli...
# 1    images/2019/12/20/nyregion/20queenssewer3-prin...
# 2    images/2019/12/18/world/18xp-harvey-1/merlin_1...
# 3    images/2019/12/04/climate/04CLI-KEYS1/04CLI-KE...
# 4    images/2019/12/03/world/03phylippines-typhoon1...
# ..                                                 ...
# 653  images/2013/05/30/world/swiss/swiss-master675.jpg
# 654  images/2013/05/29/nyregion/29cityroom-coned2/2...
# 655  images/2013/05/11/business/Money1/Money1-maste...
# 656  images/2012/10/31/nyregion/FLOODZONE/FLOODZONE...
# 657  images/2012/10/28/us/29storm_earlyss-slide-EW0...
#
#                                               headline  \
# 0    Severe Weather Across Europe Leaves at Least 9...
# 1    Raw Sewage Flooded Their Homes. They Finally K...
# 2    Government Liable to Some Hurricane Harvey Vic...
# 3    Florida Keys Deliver a Hard Message: As Seas R...
# 4    Typhoon Kammuri Kills at Least 17 as It Powers...
# ..                                                 ...
# 653  As Glaciers Melt, Alpine Mountains Lose Their ...
# 654  As Hurricane Season Nears, Con Ed Shows Off Eq...
# 655  Rebuilding After Sandy, but With Costly New Rules
# 656      For Years, Warnings That It Could Happen Here
# 657              Sharp Warnings as Hurricane Churns In
#
#                                                web_url
# 0    https://www.nytimes.com/2019/12/22/world/europ...
# 1    https://www.nytimes.com/2019/12/19/nyregion/qu...
# 2    https://www.nytimes.com/2019/12/18/us/harvey-f...
# 3    https://www.nytimes.com/2019/12/04/climate/flo...
# 4    https://www.nytimes.com/2019/12/03/world/asia/...
# ..                                                 ...
# 653  https://www.nytimes.com/2013/05/30/world/europ...
# 654  https://cityroom.blogs.nytimes.com/2013/05/28/...
# 655  https://www.nytimes.com/2013/05/11/your-money/...
# 656  https://www.nytimes.com/2012/10/31/nyregion/fo...
# 657  https://www.nytimes.com/2012/10/29/us/east-coa...
#
# [658 rows x 6 columns]

# %%
df_list.append(get_nyt_api_images('20040101', '20120101'))
# Out:
# Beginning requests for date range 20040101-20120101.
# Sending request 0 at time 0 s...
# Sending request 10 at time 131 s...
# Sending request 20 at time 262 s...
# Sending request 30 at time 393 s...
# Sending request 40 at time 524 s...
# Sending request 50 at time 654 s...
# Sending request 60 at time 786 s...
# Sending request 70 at time 917 s...
# Sending request 80 at time 1048 s...
# Sending request 90 at time 1179 s...
# Image links received. Took 1312 s.

# %%
df = pd.concat(df_list).reset_index(drop = True)

# %%
df
# Out:
#                       pub_date  width  height  \
# 0    2019-12-22 18:43:45+00:00  675.0   450.0
# 1    2019-12-19 10:00:24+00:00  675.0   450.0
# 2    2019-12-18 10:04:31+00:00  675.0   420.0
# 3    2019-12-04 17:55:29+00:00  675.0   450.0
# 4    2019-12-03 07:37:28+00:00  675.0   450.0
# ..                         ...    ...     ...
# 657  2012-10-28 14:14:53+00:00  675.0   449.0
# 658  2010-09-11 20:32:44+00:00  675.0  1013.0
# 659  2007-12-16 05:00:00+00:00  675.0   338.0
# 660  2006-09-29 04:00:00+00:00  675.0   463.0
# 661  2006-04-18 04:00:00+00:00  675.0  1013.0
#
#                                              image_url  \
# 0    images/2019/12/22/world/22europe-weather/merli...
# 1    images/2019/12/20/nyregion/20queenssewer3-prin...
# 2    images/2019/12/18/world/18xp-harvey-1/merlin_1...
# 3    images/2019/12/04/climate/04CLI-KEYS1/04CLI-KE...
# 4    images/2019/12/03/world/03phylippines-typhoon1...
# ..                                                 ...
# 657  images/2012/10/28/us/29storm_earlyss-slide-EW0...
# 658  images/2010/08/11/opinion/brisbane/brisbane-ma...
# 659  images/2018/04/02/opinion/thomas-l-friedman/th...
# 660  images/2006/09/28/world/29water.1.ready/29wate...
# 661  images/2011/03/29/science/science-claudiadreif...
#
#                                               headline  \
# 0    Severe Weather Across Europe Leaves at Least 9...
# 1    Raw Sewage Flooded Their Homes. They Finally K...
# 2    Government Liable to Some Hurricane Harvey Vic...
# 3    Florida Keys Deliver a Hard Message: As Seas R...
# 4    Typhoon Kammuri Kills at Least 17 as It Powers...
# ..                                                 ...
# 657              Sharp Warnings as Hurricane Churns In
# 658            Readers’ Views: Equality Among the Dead
# 659                            It’s Too Late for Later
# 660  In Teeming India, Water Crisis Means Dry Pipes...
# 661  Giving Sacramento Good Reason to Have New Orle...
#
#                                                web_url
# 0    https://www.nytimes.com/2019/12/22/world/europ...
# 1    https://www.nytimes.com/2019/12/19/nyregion/qu...
# 2    https://www.nytimes.com/2019/12/18/us/harvey-f...
# 3    https://www.nytimes.com/2019/12/04/climate/flo...
# 4    https://www.nytimes.com/2019/12/03/world/asia/...
# ..                                                 ...
# 657  https://www.nytimes.com/2012/10/29/us/east-coa...
# 658  https://www.nytimes.com/2010/09/12/opinion/12p...
# 659  https://www.nytimes.com/2007/12/16/opinion/16f...
# 660  https://www.nytimes.com/2006/09/29/world/asia/...
# 661  https://www.nytimes.com/2006/04/18/science/18c...
#
# [662 rows x 6 columns]

# %%
df.to_csv('../data/nyt_images.csv')

# %%
df = pd.read_csv('../data/nyt_images.csv', index_col = 0)

# %%
df.iloc[0]['image_url']
# Out:
# 'images/2019/12/22/world/22europe-weather/merlin_166255482_a49b6b8c-dae1-4c7e-babd-de79ddb1e167-master675.jpg'

# %% [markdown]
# ### Download all images

# %%
def download_image(image_url, image_number, start_time):
    if image_number % 10 == 0:
        print(f'Getting image {image_number} at time {round(time.time() - start_time)} s...')
    
    res = requests.get('https://www.nytimes.com/' + image_url)
    assert res.status_code == 200
    
    with open(f'../images/nyt_image_{image_number}.jpg', 'wb') as file: # write, binary
        file.write(res.content)
    
    time.sleep(3)

# %%
start_time = time.time()
print('Beginning requests for images.')
for i, image_url in enumerate(df['image_url']):
    try:
        download_image(image_url, i, start_time)
    except AssertionError:
        print('Bad status code at image {i}. Stopping.')
        break
print(f'Images received. Took {round(time.time() - start_time)} s.')
# Out:
# Beginning requests for images.
# Getting image 0 at time 0 s...
# Getting image 10 at time 37 s...
# Getting image 20 at time 73 s...
# Getting image 30 at time 110 s...
# Getting image 40 at time 146 s...
# Getting image 50 at time 183 s...
# Getting image 60 at time 219 s...
# Getting image 70 at time 256 s...
# Getting image 80 at time 292 s...
# Getting image 90 at time 328 s...
# Getting image 100 at time 364 s...
# Getting image 110 at time 401 s...
# Getting image 120 at time 437 s...
# Getting image 130 at time 473 s...
# Getting image 140 at time 509 s...
# Getting image 150 at time 545 s...
# Getting image 160 at time 581 s...
# Getting image 170 at time 617 s...
# Getting image 180 at time 653 s...
# Getting image 190 at time 690 s...
# Getting image 200 at time 727 s...
# Getting image 210 at time 764 s...
# Getting image 220 at time 800 s...
# Getting image 230 at time 836 s...
# Getting image 240 at time 872 s...
# Getting image 250 at time 908 s...
# Getting image 260 at time 945 s...
# Getting image 270 at time 982 s...
# Getting image 280 at time 1018 s...
# Getting image 290 at time 1054 s...
# Getting image 300 at time 1091 s...
# Getting image 310 at time 1127 s...
# Getting image 320 at time 1163 s...
# Getting image 330 at time 1200 s...
# Getting image 340 at time 1236 s...
# Getting image 350 at time 1272 s...
# Getting image 360 at time 1308 s...
# Getting image 370 at time 1345 s...
# Getting image 380 at time 1381 s...
# Getting image 390 at time 1417 s...
# Getting image 400 at time 1453 s...
# Getting image 410 at time 1490 s...
# Getting image 420 at time 1527 s...
# Getting image 430 at time 1563 s...
# Getting image 440 at time 1600 s...
# Getting image 450 at time 1637 s...
# Getting image 460 at time 1674 s...
# Getting image 470 at time 1710 s...
# Getting image 480 at time 1747 s...
# Getting image 490 at time 1784 s...
# Getting image 500 at time 1821 s...
# Getting image 510 at time 1858 s...
# Getting image 520 at time 1894 s...
# Getting image 530 at time 1930 s...
# Getting image 540 at time 1966 s...
# Getting image 550 at time 2002 s...
# Getting image 560 at time 2039 s...
# Getting image 570 at time 2075 s...
# Getting image 580 at time 2112 s...
# Getting image 590 at time 2147 s...
# Getting image 600 at time 2184 s...
# Getting image 610 at time 2220 s...
# Getting image 620 at time 2256 s...
# Getting image 630 at time 2293 s...
# Getting image 640 at time 2329 s...
# Getting image 650 at time 2365 s...
# Getting image 660 at time 2401 s...
# Images received. Took {round(time.time() - start_time)} s.
